# %%
from resource_change import *
from common_function import *

if __name__ == "__main__":
    
    sample_dir = '../sample/input_sample/'
    save_dir = '../sample/perturbated_sample/resource_change/' 
    
    samples = list_files_by_size(sample_dir)
    create_directory(save_dir)

    for sample in samples:

        if '.ipynb_checkpoints' in sample or ('.exe' not in sample and '.dll' not in sample): #or 'calc' not in sample:)
            continue
        try:   
            change_resource_case(sample_dir+sample, save_dir)
            print(f"Resource case changed for {sample}","\n")
            
        except pefile.PEFormatError:
            continue
            
        except ValueError: # 샘플 확인해서 해결해야함
            continue
# Out:
# Directory '../sample/perturbated_sample/resource_change/' created successfully.
# Resource case changed for dd1335bc3a8e64775d3e50e96e86b9c5287edf1d15131292c2d7d2a1be06fc33.exe
#
# Resource case changed for d6ca937b595f49b770fee6b7a8a304d2d82cc861411e008bb75be8cff87363d7.exe
#
# Resource case changed for d00df5a2d57054c71af4a63e6593e875a4ca9bbc836cd495d4204d0899921572.exe
#
# Resource case changed for a4e63c6ba0e3cb9ba7c90f6803255e4692dc31a1d051c7c71aecbe50d6209168.exe
#
# Resource case changed for b55ceb3c0eacb26dd3d14d8f2ddc203d6664acdf06179204e6bf320a942a438d.exe
#
# Resource case changed for 0b797c9efb374e8f6bc49057367a5b3fc3c6e45885a476953b102c971698d8dd.exe
#
# Resource case changed for ad91d4f5be9178df7b570e6db5a8d1fded1a95e843b30be108ed821b33504b33.exe
#
# Resource case changed for 922fc59597bf515d542b5f928fceb674d3aba5c071d8408ce008c9eb56b3c411.exe
#
# Resource case changed for 65d985debfd483eb49b40c58a3ff22641391a7cd6122784b23d439c49d034bea.exe
#
# Resource case changed for 6c9feb09c2f76717829b2696c2ebe59d11b2ce69d4bccf698fd3aa0ba5c3fd21.exe
#
# Resource case changed for 80eb8ce64b5a7f0ad6de549c2b13488a2fe0a646fd9867b46c1a008a101f2b20.exe
#
# Resource case changed for 8ce1c8b15d00efd8cfb7f6a37e6cb1228bba48bf7dba1b1718503f94c18a41cb.exe
#
# Resource case changed for 5e230983c5cf48e34bb571707b5628bd115b4859a01451237ee90e0272caa214.exe
#
# Resource case changed for 1905ed6f2a1e5cbc8703d3fa2ad3ad5b387313ae53741929984a2a654d21271c.exe
#
# Resource case changed for 87b620874ca713069f7f939075f4b79a55d41e6f58b8220fd708aa553ce0a95d.exe
#
# Resource case changed for 7e217b0890474b2a7c64a609d8fbd05e7263222c11b68cda8bd8f5e026f00004.exe
#
# Resource case changed for 2dcaf04e65e095b0087b7bf354d6498a8a7c7fd4789d2c0c9516c13bd1c6a310.exe
#
# Resource case changed for 1a5984c35777add7ef677cf4a47b89507ff8af16065ee62684e3b11b3bc22057.exe
#
# Resource case changed for 6c73997289762d471424e440c7e92964244ea8791d63e4bdae50c839d999fef6.exe
#
# Resource case changed for 620bae1ab9de6fa46fe9eae40169f00e74374d9df32bc87c1a6a2954a70a6dce.exe
#
# Resource case changed for ff53961b0c64c883c3c5e1a93f714420f4e507a46a6914a60362b922d5510184.exe
#
# Resource case changed for 8896ad8d769cc6181196b4042f78f9d13a4919669e52841c2cfb932d4b47a8ba.exe
#
# Resource case changed for f70d22e1f46240cea9175fa3d738bcc344787a8f47c4be325d8da0fbfb308eae.exe
#
# Resource case changed for 2c4d1274135a9274d00f5f680b95fd32395b45866948649d9ecbbbcb1dce01d1.exe
#
# Resource case changed for 334e992726b49be1dd79ac1c849fe749902136cbc072f2bfee30a43325aeaf0f.exe
#
# Resource case changed for 99c6e61c3c6a494d268526b8ae36e36e6477793ed2f79172fd473ba38ca37c1f.exe
#
# Resource case changed for 0078e3961d934fcf2782d77812d2ba7177e23207099333a0cd084682ca0ef3ff.exe
#
# Resource case changed for a969edd33554844b0539be7c6fa28be42ea72903792720fee2fb6fa24344b93a.exe
#
# Resource case changed for 898c986c60c67e4d3b01014628542dfa3baf149aecc47816a80e470a12b305eb.exe
#
# Resource case changed for ab3d6a40ee78f88d6040b973bf1fa10e25595bf3a3a816d17e63daa2f0d72ed2.exe
#
# Resource case changed for 72e53165e787f549bc609970cda99a8c6a392e697cc501a0259e91e4599dbcad.exe
#
# Resource case changed for 233963cb511540091e199dbeaf48ba4b3a79d59b724fec930ecd99a699d8e0c0.exe
#
# Resource case changed for cb8621794c9c83eca1939b5d48ef644db2fb1402dea7fc5522f41846062f39c5.exe
#
# Resource case changed for 76d5eb9ac24984de0e5a7e108e77e8c9d2253065ff293a2c84e212c9f55a5a0e.exe
#
# Resource case changed for 9fa7cd923af221b8930a42139f9c22fdef871ff7eab41c54801ddcb7e676dc9f.exe
#
# Resource case changed for 9a2ff0ef242f0d2813ffa58e856c0bd6ff7299c0987319807a2dc89ab031b773.exe
#
# Resource case changed for f3c332e243fad61ed748ec5788fba1fe659c4d776f989fb4fa3be2ec035ca178.exe
#
# Resource case changed for af5c9904b3eb4beb59f80a85a97c91b652a4cbd297254edbc0754935e85f8f25.exe
#
# Resource case changed for bacaec79a6c419ddfb6a9b1ec7512f549b9ac66f2ecb5cf38aa8ce3d31175ada.exe
#
# Resource case changed for 25df514d939c5cff457577a64bd51e89a5b826c50f66ff7f9260b617e84e9f46.exe
#
# Resource case changed for 0923fef4732c5b5a71f1bdd10ca75b59fd9a0590fc883a32d434a375689835c8.exe
#
# Resource case changed for 8773e41e731ea7936de9b28bc7760ae88431ae81e20a3dd0d639fc92e80efd9d.exe
#
# Resource case changed for cc2036401f6a573eae65382adfb45b8659d755013fec3fcf8863c4fdc8b8dcba.exe
#
# Resource case changed for 185eee5d2b5295185f1e5ec11cb889f4b134d54cca911751ca5f291183e8d86d.exe
#
# Resource case changed for 26a9022148303f7cc2c95a782aa3b13b18f6af05b3d28a18e93754c8bc6b28e6.exe
#
# Resource case changed for af4358b5750bf88e663b6abc3aaf1b003f03cdbcf7d1de2f1268953dddc1b7d8.exe
#
# Resource case changed for 53d712ec84e32355dfa7e224233b7f880fd1323d511e08bff470a6c7b043caa4.exe
#
# Resource case changed for 78f77e014327bcf8644aa46c6f491504ce4d23c44841f9090d15705f452e3172.exe
#
# Resource case changed for 50c668f03fc66e8111f63e7005417226157fa6bd8755a552dfb419103ace0738.exe
#
# Resource case changed for 6a94a4a1e154a240d6803bed560b35f750b9398105e4f69537ba7a7359b27110.exe
#
# Resource case changed for 1b99720ff518a77349947048153711262cb9bda67b98b654cd025426c440cbef.exe
#
# Resource case changed for b5b9c647116d49ae8672b0e5c953fd5c3ef4b1dcc117cd4c87cb52791c65fcd4.exe
#
# Resource case changed for 9d6274fa1ca39115f9bf032a669a2cea7a60ba8c72d7e2b25a2074178f836311.exe
#
# Resource case changed for f8166c9893da033b375d2f413b813f21ae3b67fb26dbba145af6382ed97bfdef.exe
#
# Resource case changed for a219b211338a8586c5c0f89bcb6eaea6ed28cee1f76231dd163e66c299efc566.exe
#
# Resource case changed for 84212bd32f7a1624b2fbbe5318d76a27cc2b5e48d162b401196fd4562c941cf5.exe
#
# Resource case changed for 197ecd7d2f2bdcb3f1b3320a87f9028ff4b49d287a17c3acf4714cd5b0cef89e.exe
#
# Resource case changed for 68d0c6719aabca69f4b0714a2a1122b4c95d55d282523fe1cd6fb750ea3c16db.exe
#
# Resource case changed for fdaac7b70f6cb062af203687b7ead65e269959ee9243d3042f2dd3f0ba4fdbb5.exe
#
# Resource case changed for abdd1e87c06fd7aa29850f32468f7bc27ccb694c38fd56e5584aa5f828e1e12c.exe
#
# Resource case changed for 086b7bdd1d78ea491b8290a3bb361c50becd3cd784b8076586ab5b0236bccbe2.exe
#
# Resource case changed for 430c7c0a11333d4eb0846004f59508b12c7fc3759772cb6f5dfe217cfcbf632e.exe
#
# Resource case changed for 40d4f3bb30bfdec6eb249fd614cd42f012a4375ced8ea2fb9ce31fb17a5a2b71.exe
#
# Resource case changed for d0cb0d8b10217e3e8fc913f37326f9e9f27061e252a051e0d0afd008bf2a69a0.exe
#
# Resource case changed for d5e3adf1a531165e3e2ab3b0c452cafe3d883a8a679462259d8f2a64304bcac5.exe
#
# Resource case changed for 52a4122567edec5b552770697913ed9028e33fc8d02a90b3a2a15e4e9eac1c14.exe
#
# Resource case changed for a9dad1e5a24d83c51643a7c66340cafea5c423dd75185b88860f96749d5a82ea.exe
#
# Resource case changed for 3a2b8b010d844cacfe14b44465d09e4ce938b5bca8f9c5b4d5a8338f9f00d85b.exe
#
# Resource case changed for a66b0fbbb78110c04802d599168256b6bdfb2b45c6d1d9bb3f68b5b9e4d77cab.exe
#
# Resource case changed for f2d05a3f29241ed9ee9b976531e59ceb6155609b2e5bc4eaf15867c9ff2f5588.exe
#
# Resource case changed for 20d8c443443f3ed5d4f1893200d8718cf8315e94c6a89cbbdc0a8c969bae371a.exe
#
# Resource case changed for cdb3640a51be469fd01b71148a7296a84fcac4cc08c9b39d34496f5485497196.exe
#
# Resource case changed for f2c4f14eac7ee34666a2e5214a4e5db76f7cc1edd86280da876f1d01d1386e89.exe
#
# Resource case changed for 3a1b797876f0839e861ea4a5a44940a4fdcf84c91c12a9ff2c1f09ed01b690e1.exe
#
# Resource case changed for 52b86b54dd5f5f53099da654ab413b09620f57b3bb8d9700e425b4bcae211cf9.exe
#
# Resource case changed for 6d5737ba5f9c55a48f9672d1aa47ebb82a8df99b678409035e8b675bcd11b0ac.exe
#
# Resource case changed for 9b27db770696e351b1ce2df472cdbcf9ce8dd1d325741abfd4ef5cdc4e7fad4c.exe
#
# Resource case changed for 11752e076b157d5f4daa610279643bdcf038bea3357696c4adc4b9d2e4df3832.exe
#
# Resource case changed for 2c127f91b268a5e6316f343781451b76bee664638987ff6d17622be8def3f864.exe
#
# Resource case changed for ec1f7e652aa8f48f6ad478b60b7c5104211d66a5410da450e852a9f1283a4cb5.exe
#
# Resource case changed for 3a101185d6dfae71e84fb1c37bcd07da18d34b084ab6837d1c49f1bd99642bcc.exe
#
# Resource case changed for 176f3ad6537a7c5f84d038bb961b14f28eba7ed32883bff4cca87581b978b657.exe
#
# Resource case changed for 7108cdcdfe97cb004cb82d7be93c2d1ad7488596ffa98b3b24bb5df5b31cc739.exe
#
# Resource case changed for 524c03385d015de420537ef39dde0bab2f4a25a0f58ab01155ea48cd13a07447.exe
#
# Resource case changed for 94c15ef428966485b95181069f593131fc5b31ed2bd940a580e70214c06150c3.exe
#
# Resource case changed for b886d25bfe6e98a2e974d38d8d87bc1d0f53cb26694736533ca0a6a52e18f7b7.exe
#
# Resource case changed for caee4fd297b7ae74fa2383b507422f8869ae551baf6a4c4a42a3b95ec2b4d584.exe
#
# Resource case changed for 522943674e5deb54dbc0203f075cbe0ca3ec24541059ab7497ec9122804ac88c.exe
#
# Resource case changed for eb474ae6e7395e126c44dd90502885e15e7721938d542ad322a9b9b515dbc9b7.exe
#
# Resource case changed for d1dd03ade413852e743afe2c1d1dd515b4a167add59e59d7bd647da23443afc0.exe
#
# Resource case changed for 0cb17078bb20234b689836ff48c147ebcdf4abc3fe82e42ba51454fe1cb4a1e5.exe
#
# Resource case changed for ea7138c94a195fd592f5ab7ae860c6e94201431a6ca487d623c3695876473cbe.exe
#
# Resource case changed for 13ab0448483994b2a8e737655a844246f5974e46f2bba4e1164518610300e573.exe
#
# Resource case changed for 66fb5569799f359e08a84901969a4429584cf83c708f1ec0cb92f1989a18ba5e.exe
#
# Resource case changed for 05482830f3f256740b428ce8a0cdf68637141e7af9715bf1facb81c9b188eac4.exe
#
# Resource case changed for 6d0338228fb76a156167342197ae7f24c1141f2d20e466000a3cd476bc8b924f.exe
#
# Resource case changed for 6964e876a24d494d67445d658f88221f5080274e2ae06ca5431318da8e25139f.exe
#
# Resource case changed for 65bef3ff372b0d8774f93781614cc0ac0f7a55f6d1ebfe8274299a22f362dd75.exe
#
# Resource case changed for b9ba3a88356a596b05c61aea4aa31f60888bd53a40c976dab277cc561d9100a7.exe
#
# Resource case changed for 2d2fa95aa9bf662fdcd71d75dc4ddb6e322b3db907d7555450c5db9def301012.exe
#
# Resource case changed for efeaff4f9874f73950ad7eea5fc000086655fd70295f04a69cf651d8adc648db.exe
#
# Resource case changed for e5d784f91ddf1ba2fa0a83ef56cbc862e427b8617be26f4d4cbc70245b0fef39.exe
#
# Resource case changed for 44208490902610f4c6ab6a5b28d9e2a762e4c74d830ecc19bbcfbfa4a6fa2d3f.exe
#
# Resource case changed for 0b3883ee2f88db3b2cd6d263f10ca27a435556d00faaf7f6bfed265b892647c2.exe
#
# Resource case changed for 158fe3158a0a0bce57a9ac5194ee5d54eb1a409dca9b6391610be0dfd630a919.exe
#
# Resource case changed for 46e6b7337ec9733619ea3730f9b30986dddcbd9f5eb12ff6a0f8fdab9f49aafa.exe
#
# Resource case changed for 69f324023c52b35ae7b9419e3cefe21c38058b78896534c7a7a033408ae6263a.exe
#
# Resource case changed for dc0d1b7e5bcaa50cf1c7f738246753b7e0a30897c3e70e832f344e795ad801e2.exe
#
# Resource case changed for 95cfef141f5da2813f6e20465cdfc0ed9a2ea83129a1fcda053309853665b0b8.exe
#
# Resource case changed for d2c49efc55a5478b04e397cdf872200fb31dfcddca2c49cde46dffa41d49a9a1.exe
#
# Resource case changed for 61285765aaf3e61255f011f8abebdeeb4d93d40ca8157f3cd32fb11fde7b2bbb.exe
#
# Resource case changed for 8fba924ddaf2ef6fd02d908cd3df7fbc89188ed75d7efb98d77917043119f656.exe
#
# Resource case changed for 2ace50a919b3ac2f740f6137f0d178282c8efabe4be73d7e9f7538c775aaf55b.exe
#
# Resource case changed for 3a1507fbae21d3f27d13066bb56dbd6ac4c7a7c4598ae3bf8e0a218b6d6b0088.exe
#
# Resource case changed for ccd886f017cf9e046e0657773d2fd1812d60e018066bae7fc57efa8d83058957.exe
#
# Resource case changed for 0fee54da832c59eeebc1145b86b07bbc8a6a6d6d6f439e638d2c379e73b59f59.exe
#
# Resource case changed for 685cf5034b0878fd65e048b2b4b1ca26141ce9ad30f65d8e7390409e6a497039.exe
#
# Resource case changed for 06a428dd5a543e67f25b02ccd7efa77d8f2cd7fe67bbfe2184d2023b16aa152c.exe
#
# Resource case changed for 1cfc4c0d683192cfa1446520d33f425b5a68ad8722d0ebc83dec38e81e4e2cf5.exe
#
# Resource case changed for 64ad90d80f56306852283ed5809c67970703dfa5dee12e618214b173a277660f.exe
#
# Resource case changed for 8ba7d0adb180615be8923a26b3c3259201a73f0cb70b62f38c2d43445c2e8307.exe
#
# Resource case changed for c72860dfe38d3a94bd7c16fdda00fb3d2657ffd7faaa36be6f033dbe9ccaa284.exe
#
# Resource case changed for a1d42adc7d69faaa28a5ecba7c4b65cf0ea61bea506f01de59a1144e13fc2851.exe
#
# Resource case changed for 76a59ba7ea2ece65f2fc9a69b4b386f3a3a78b2a74a17642837a19b61a3a4f3d.exe
#
# Resource case changed for d2ba2101cf2fd2fb828d523c831626a47b8407fb94429fa8e682556b0b2ccd05.exe
#
# Resource case changed for 39a9655c4ab3e90dc79f5a3d00add4a2f3a37baabead877d5d3c029f8e4047fc.exe
#
# Resource case changed for 7acfd653701c03f7bc055bd9c26aefdb63b3e5a63d1c1cb034a091af8d10998d.exe
#
# Resource case changed for d7b9f586cd8ecd8864d5d49feb89fd58e8588debda3b16ccf38e3132841477a4.exe
#
# Resource case changed for 0eddc7ab734587c32dbc9cbd68f2a2efd6acade721bad6f641378c56351ed80d.exe
#
# Resource case changed for 587af9b5783de44108aeb44b588e2fc7e3f92bf670588a244aff58b64a26a43c.exe
#
# Resource case changed for c20e9208750f47a286b121d44d9d2bcde6f6386913df5eb79aa20bb2ea80dda3.exe
#
# Resource case changed for cb87fb4c4945e7269496d45931237efc140d3019abc81d3b436d37a7a6418d09.exe
#
# Resource case changed for 4f6c04a4374aef3f0d123ac90672bc2095861c6e60e11d330cb52498621bc975.exe
#
# Resource case changed for 80dee8c3daaf10d404a7372e59674b234913eed413d8848f7e2e13dabbb25a24.exe
#
# Resource case changed for 3b3509f63c9c5930a03f8c28772ec311e09d22c5d487a3533fe58be8341f8d5d.exe
#
# Resource case changed for 9bcb69c5d5db10b50143b9f7b0b2f73895c863ebfbce6f747c8708b264765e83.exe
#
# Resource case changed for 34f7cd0b6a340c6d1eba0da60810f8d9833561715838cce8c407c279de04b1ec.exe
#
# Resource case changed for 11668696918a1745480fa2d147064b39712995877417cb146581b8a5ebd14e2b.exe
#
# Resource case changed for b1b9a9fa14c13bad7eb1b3c029c6e24ee6cb31b355ec9ac1234674ac56b09a6f.exe
#
# Resource case changed for 40d9b777a449aa99eb1e7383dfa3f157f2a83c24103097ee75747196d36c107a.exe
#
# Resource case changed for 71aa40913aed1ff62439f746fc0fbd756b83e18024d7f8f16557a0dde2db021a.exe
#
# Resource case changed for ec7167294c8a5f1cad597c35cf61f6d8b076b3f9a865771e4224965865fa5953.exe
#
# Resource case changed for dd693715430cf28a06c124f7fa741c1d86a75ca8ab6009cee5e32fc5dce22a43.exe
#
# Resource case changed for e45d91149d13e62f9da72283eadc97d317bfcf315e28ad3c2c2fc3c43641e694.exe
#
# Resource case changed for 2e73f1d92d6e05650e6d0562a0a892e6cfc4d789c42dc17d7081c8233ae24a49.exe
#
# Resource case changed for 018030ca511a930052a5cf1111b78f39ea941f8a41e08179fc938f98862b6c62.exe
#
# Resource case changed for 9336e7a87e759b9f442c77c49085475143a6a45be78a4603f00e7e0eb2844758.exe
#
# Resource case changed for d41ac852115d5d3b67b34ecdf9c0e50e4772d83bee4c85f2e300f00646f07f52.exe
#
# Resource case changed for ccc0cea19392121d029bcf425ed2715ba0814fd442e45d36a5dd7be7b195ad2f.exe
#
# Resource case changed for 4e9858475702b48ee1c514c43a13649ece3e52e84a72fe79a038d92e64ae8b8c.exe
#
# Resource case changed for e6c9e1a5cc9d702b950ddcfc675c236cd12da354e13112f963d95e4198d192e4.exe
#
# Resource case changed for 9543221a3b20e273d0bb91beb90f7547aa993e5f88d50a5950558c7c2a38cd15.exe
#
# Resource case changed for ed12d5c46fbba060d24030fad22ef4ee4cee9ad89d40bbe38a3e1f4b7ba095f4.exe
#
# Resource case changed for cf4af5a28c413d6a3e5315edfeaae7b565959e45ad02a66b8a52dafd35e1c300.exe
#
# Resource case changed for fc29e40f62969a903520d1d5c66d1dc84c20f1724f36262fb1826cc4b548bddd.exe
#
# Resource case changed for cc93fd5bbf53c09c4b4033e60a2d17e87c488738da65a413c44aeff0a823145a.exe
#
# Resource case changed for 1563427648a363944c645b105f665f4f5a75cdf897f454feb41669394a6c0da0.exe
#
# Resource case changed for 12b911b7ffe3866bc85452e111d5ee1743ca6a594595d994c8692c9df5a9d6c4.exe
#
# Resource case changed for 48e3617ce7eda8fec8fde05ab5f9682db730f43ed7509cf921f1422804c9d9ee.exe
#
# Resource case changed for 2b2934b6b4b78ae997653e4df2ff4dad7bfd8a9e3d1039350a37d0a052c069b0.exe
#
# Resource case changed for dfdb34728b524b0adfd103d52497f166cf7b341b2db0ae0cd455988a4a193b01.exe
#
# Resource case changed for 15a5e7452155069444548108da7855ffb5bd31dc2440f4a47de73f53d81eb23f.exe
#
# Resource case changed for 97f647ab10e7e50bbf3cdece484f606198741103efb73324dc03a6cacc4c28ff.exe
#
# Resource case changed for 55d35fb418ac07fb27f01ad9553e67511058ad72469f6c80238fab36bc3f4e61.exe
#
# Resource case changed for 960c08802324d01663b7d9d19c5791271fdc649c93f62ef57270d17e87705b3c.exe
#
# Resource case changed for c5d5517bee451051a67ff84ccfe185be2a9983c5902e26798e9366e2f394f111.exe
#
# Resource case changed for e381bbf479b01b4cde27563f385a219a28b16c9c703154233efe2473d866af28.exe
#
# Resource case changed for 4d85e7dd4511fd4a1591d19c27126749170d04f5fc4bfb1980701bdfcf87363d.exe
#
# Resource case changed for 93c63bdcac08f5a76f2a47751779aa8d1e56dbc4758314f1961a07e0bda7448f.exe
#
# Resource case changed for 34616544a302ba718b5c12e649a6a1e38ac9a3457cca78d93df5a0b2d0919af5.exe
#
# Resource case changed for be9c4306b2ada9eaa70fa88a9bd2f2949cd89e7fc2c10e9730bd120f434c38d5.exe
#
# Resource case changed for 436349befc1110fb89c8d77cb2b0e4e1aa282c67b10ad32c5de20a19bcf3dbf2.exe
#
# Resource case changed for 47a7ffff18eb21e2e18b292a4970b6346919c496035b92d70ce2b7d4aa006bc1.exe
#
# Resource case changed for 6649211ba6dc0574919c296e2bb79d5f1985f36ab9979b86980f355ab4d2077c.exe
#
# Resource case changed for ba302ecb42e6e8809ffc4b4735caa86df0a992961ece651643f611768385a265.exe
#
# Resource case changed for da6fc269f434747f4b9b3743adf43eecab7c58c902f3c226a70898b11ff2a2b7.exe
#
# Resource case changed for 1b5d50ff605edf7fa7a571dd446049fb4a33998f1f402b87256d39f809206121.exe
#
# Resource case changed for 20300cb6afc577b4fa69c653cadb3d945dd7960ec2353b68af667f91b52a1a39.exe
#
# Resource case changed for c21fd428ae8b740ef0ce2a73060e908b039df192cfc13dcedb4460411319488f.exe
#
# Resource case changed for 8804614370899a14f2397014972a506553d0ec898240797d71070fd7daac0b75.exe
#
# Resource case changed for 23a851e66a8b203aea62c05587ffa735e9d8a5b32af4cc30e34c54aedaf52bb5.exe
#
# Resource case changed for e1b8d5aaa188f7c5976698e1ca9f45729bcaf88b3f1454b42665443dd46d714b.exe
#
# Resource case changed for 3f6d0c35808d63fad2eca52cf00904f33d1fe3f2b3812f82f2dcca67c4a83dca.exe
#
# Resource case changed for 6bfa65fe065a9d06a7fd0248fcb62a8caafaa699a1df36605bca04aa6cc3b121.exe
#
# Resource case changed for 4ffa974be2806323a09dc1914ef1540e0788d289ae7f0d4a9eb58274068f4715.exe
#
# Resource case changed for 3d6a9abcdcef4c2d379be5f6825532784bf9676480b20f44d8e9deebeb43010e.exe
#
# Resource case changed for c3d091955bad27849c19b4e239ad578e0c1290a65a749df6a951e2efd97ae047.exe
#
# Resource case changed for 109723a583819eb2191423deda023a7925c9dcc3ba7085415494fe89be8f03e8.exe
#
# Resource case changed for f372100b7aa1068ed28b7d470e936ba9da2eef65382846454fc006dbeb75977e.exe
#
# Resource case changed for cddfed0b88c45808d4813a0315b581c7b8ecf2446c9134123c5b5f3ff9351d78.exe
#
# Resource case changed for 96fe0c01c26ca1ade79a6a69c03352efc5770a36c8893daecb7f5b079472b2a1.exe
#
# Resource case changed for f76145bdf4ec5874df08a9ea703dbaee29fb442a9961baa6f2112215f65b6fe3.exe
#
# Resource case changed for b0ae6dd953249659995dad20c811e09e5cf03484830e47a9ed7860dec7fe7a00.exe
#
# Resource case changed for 9e04d6ad759076e19d68d678c44c84b0e2330a559a22fbae744cea9635d6ce4a.exe
#
# Resource case changed for 8515f169d12c950485b1d7ba531b5ad234fb8ecbc4e16b918784ba47a26e3340.exe
#
# Resource case changed for 2af824810975b0d7a828fa1895f78f8619fc070b5331286d9cb8ad6c326c7d50.exe
#
# Resource case changed for b09b1bfc7d2cba8a27f7c3424a18ab31ce7959ce820aa3ca70301eb53128917a.exe
#
# Resource case changed for 113e1abc1313d617f2c20112a9b8e94a04ed8ed26383ec67391bfad9e959d9ae.exe
#
# Resource case changed for 5f865e76035d996ba10fa689df35eb07e8d70cc8ad77f01650afb9a2df80e177.exe
#
# Resource case changed for 3a24d29c1a065e91aec7a013423245572e13305e9f65ba5a8dadf3102fbfb754.exe
#
# Resource case changed for 3638fdf4c0406b00b9f9dded8287ae45fdea54dd443543f17961dac837395263.exe
#
# Resource case changed for 5edee5900f5e028658ebb9979ace6308cc531a28c937b2837c4134b22c131f1f.exe
#
# Resource case changed for a37345b54d04771c5a2cb99efaa897d44e507ac93a8250995b4b61f64c51fab0.exe
#
# Resource case changed for 9213eb437b56eb9c4118543162066e6d0a7f09ada48d0212fdf114e3064fa53f.exe
#
# Resource case changed for 1894feae423bec6423d21de627d05432c46757a6169e58001afe632ac38e8fca.exe
#
# Resource case changed for 7cebcde7e894b1522bb4a462d21df06caed147c84b2913a076c3021c649347de.exe
#
# Resource case changed for d5ecd44a7bc251a4b236b6914034dac1c3e5370d62259451f2542c8ee584d568.exe
#
# Resource case changed for c9f9cbddc27b0e7fa8dc235d8babeb4a1aa28d8755b0d6e492955a68bf1bc807.exe
#
# Resource case changed for d3057293b406f52616fc8c56829018ccb94292eb5c69043817d58f08507e8710.exe
#
# Resource case changed for 782756635ca45f8096d9fc5432d3542d510609d18adf3dc2dd339e50f0a2e5fd.exe
#
# Resource case changed for 9cc145f400d0bcbbe40d935bff1b4ac85d1f2d9aaf2e3ccb5f4f3604b11fd4a6.exe
#
# Resource case changed for 663978070e2106267035c143e8fab755fd0ccdc17ba99e41afb0c38497705cdf.exe
#
# Resource case changed for 2a83e6d39155b9c120d706831431b7fff5f00205e3970d3935fa969b13b7fd3d.exe
#
# Resource case changed for ae74a2550835363104e196f4ec0fdf29fc01c6cceb25c18537878136d6fcfaed.exe
#
# Resource case changed for d3df5302663021958c126200feddee4af56d66da8c3dace8146eb6806e5eaf9b.exe
#
# Resource case changed for d31ff6c91bf43fc03b19a0461bb3cc407cfe9cf58d86e852be5ec00cb033490e.exe
#
# Resource case changed for 678b08b6d6f9ef523a45f6cff9e3a8f331cb8fc7151c37fd0a7b27a29546fb39.exe
#
# Resource case changed for 984c5c2d9924df2d6c0e4c12a8ea6c251b1de019c340c89a2af8211af75cdaa8.exe
#
# Resource case changed for 8078209e58acd9d31196c9a9be28f6b0ff0d6b12da8a60aff18af3fa304bec75.exe
#
# Resource case changed for 2cb6fc70f59b6c87fe288c055444c5ca6f8db5996375bf5732afa656c5101e6d.exe
#
# Resource case changed for 149901dd4a0057e477c65868027527ab63329d6109be8e907e5b110319dfef13.exe
#
# Resource case changed for fae2cda43caedb498b4ceafd2ee0c5af582eaaa966b73e1121bff245566b963c.exe
#
# Resource case changed for 0fc3db4c5e15c83d52b999b9c2e66b780fb72312234549f93f6be6d95f486916.exe
#
# Resource case changed for 41908f5a50511a0519808ea61e7940588691a3f44f8c16475f18dda95fe48ddf.exe
#
# Resource case changed for 73cc003581414c5ff23aa05f9693967ca2bc825e733290cfd00f78bdacb7b2b4.exe
#
# Resource case changed for bd9d115a774d8a6ccc4c10135cc0d462ac8191c201cb9b3297b178c41c7bdbd6.exe
#
# Resource case changed for 58c8e253d7b3a45e84a0bef86b2292af46e0ef8c71b5aeea3eeaa719ba75072c.exe
#
# Resource case changed for 42d6179e8c09fb681cc4dc740fc72f364cc04430185a17015e62a533e86f492f.exe
#
# Resource case changed for 11895fd5a74d167ca0ca570e4f23928eca77e4bce2c2ff9e0a64abc2e649bfa4.exe
#
# Resource case changed for a9c03b2e703721c96235cd8703e7b84871b2a09e0593beb776334fe971663e60.exe
#
# Resource case changed for cf32fe99c66c71f4c28d4b85846a6d9c9da00c56e2a36c5d2ffd44f4c356dc52.exe
#
# Resource case changed for 31374a4131c3961a0c393432f86712bed0920398ef0383ab8533fb036941e44e.exe
#
# Resource case changed for 19e7d660b11bf80876d966974f09e129e5cb5b5e91fb5e4221245760c1af9206.exe
#
# Resource case changed for 1a5a29a69e623c5c04fa30f67c54b0503498382558f2a0957cbea41e77fed18f.exe
#
# Resource case changed for c282e1ec6ae485d696a685d830aa73c77700e3a0d051efdb2e30bbdd703b335e.exe
#
# Resource case changed for e7ddd0ef355d8134b7adae22d4be98c898b4490390176ccd4028ffe01f7522fe.exe
#
# Resource case changed for 127d0ea2270cfe31dd36c5cf1e2e090c020d8a0cdda69b6177cad5573cba5208.exe
#
# Resource case changed for 5d0ccb58f97c7cb7fdd9fd8f5bc538a18f1c1377a2aba306964f89d38b0cd288.exe
#
# Resource case changed for 900c47fb61c62924df22d2388ef25c579dfe7accc745679e01c00313c78e1b27.exe
#
# Resource case changed for d5e5819553c978f6d7a01cdf4ad520a2fae51480e4632ef97c23bec9e80b3347.exe
#
# Resource case changed for 6ab0b4ad0270539bac307afba09b74e5cb3a77f84d199b514213a6f03421308e.exe
#
# Resource case changed for f83e975c3899f410d01fbb5d354463811a078cb0a1f0b64cf18344a1d83bd60b.exe
#
# Resource case changed for ffad26b7d92ff0273a87d9b565e61b1e7f23b31cb92691f41545e54f85d5f8d4.exe
#
# Resource case changed for 0c721326ca95022900e1c18fda6cdb4db532ae9c804228985c6df980b3be7ea1.exe
#
# Resource case changed for 60c1ba4e361a09197c872d9bdcb7df22a76cee1968f7bbcb2197b7c6639f9f5a.exe
#
# Resource case changed for 554ecede55afa067edb2ab1d3c50c340e45a68b74a7df3755610a6476eade86f.exe
#
# Resource case changed for 5b0b3f2a559d543e1ba14606e9ae2ecba30338c5080b6469c3b45c75693e5210.exe
#
# Resource case changed for 7e6d55f65605e11b9045bf0e543239fe5b07a22762d2955c079bc11aebe57bbf.exe
#
# Resource case changed for af53ff39887fdf5fc1ff5c7a53ec7f91cb12741b5a5f60478379cf7e26136084.exe
#
# Resource case changed for a186cd5bca7b3da7ab0e7152f970c4895cad9400ef44b3b13ed96f4c949cf1ea.exe
#
# Resource case changed for a68a28f1d32a3d0c6197308135c0bafef1962a57efaa34290cb84d262a77252d.exe
#
# Resource case changed for 0a8e05af1b0ee06e490e2486ab97f81ce36901671f894d6f562d778fdc90ee88.exe
#
# Resource case changed for 21a7da700aae6fc98444bb09abdcb88ece1f22ba4801d4687da23fbcc3527ba4.exe
#
# Resource case changed for 979d3fed74c9b2dfe6f35ca2b2bb084675d8d7bb4989624197e53ffc733bb03c.exe
#
# Resource case changed for ed334a2466953fa8332f3e06e74a9c6223bc4d11492fb66f4e9546bc091f9a37.exe
#
# Resource case changed for 77b1019db74ef3208cb38b6f213cd7725e9a2573019e60bb5358f7e2245cd74d.exe
#
# Resource case changed for 1aa22d2bd832d9fc58fc9d0d8b067442fb41292331500579627e0d30cc22f1d7.exe
#
# Resource case changed for 9f0e940f9d0b5eeceea449753f4813a1434e041cbca5811eff485b61bc5e3414.exe
#
# Resource case changed for 35f8a2dc66974a8a996f67b37b2b4ba7c5cbe5201d796a4b911125fa18c25957.exe
#
# Resource case changed for 1cab1a4715155b300f78e1cc77f954ab720b30453440c41a7012f929b56ef6f8.exe
#
# Resource case changed for c58b4628282be7c3037a3a91ed11fb60ce5eb6336e08b39a296ae113c634bb60.exe
#
# Resource case changed for 494b1f3f7e3a2666dca7faffa85141bb7b7388094463cc45789c3e667a1437da.exe
#
# Resource case changed for b8daba5e9c96174f1ceb56f95049fb05168e6f6f767fd6871de6c898efb56ae3.exe
#
# Resource case changed for b8bf784eb4cf1d7d41589ed2a5d1fc0c9952c7e759d54c8f491aca75f37eeac8.exe
#
# Resource case changed for 6c834c34597a1cdaa7896ea7db273e21af0b2eb5b9160b4077a7da8a7ad5969e.exe
#
# Resource case changed for d4069721274c6fa148e2b5b34b05d544b419a70de262caa8c06d491f96b6312a.exe
#
# Resource case changed for ec24d64ab4db8374a63360323f0042a8e251f08a064ed221ed0123086f68c666.exe
#
# Resource case changed for 62d1b5e5075bf6add0c6cdd0216fb39cdb4fb1f856bf8601cf2ef5dcc08279e4.exe
#
# Resource case changed for a8543130c48b4ecbd51d9e4c3a6e86425134ad5e0459d1c206bac9799d3f6d85.exe
#
# Resource case changed for 8de7187e14462f5e9efe08b67be35686d75e1d9a6c6887f5be6e831f3d8294f0.exe
#
# Resource case changed for 730168f844e250d713080967e6326b91e37569275ca4f0980331431c600f6e13.exe
#
# Resource case changed for 2899b467bd307c8a29d31a93bafca926fa72f3b4d596d68e4dfb26e5abe48245.exe
#
# Resource case changed for 3d1fb7b18a1df6f5df2a7ff6c46f77b09f73dbc5689b126cc8351e1ca476a5e2.exe
#
# Resource case changed for a8773466a910c0d45ec1706ac334bdb446684fe214be1b4f7c380b5807e3e853.exe
#
# Resource case changed for 16ca6e67e71e527d11b319cf938ccb1fe4bb5cc1cbececf45ef47968b7f4ffb2.exe
#
# Resource case changed for 4dab5064276c8d51be84e3fbb80e0c6c14b17cd1ee1c9e822e23c82a5ee76b4f.exe
#
# Resource case changed for efc4172ca6d7120f8aadb47122854507a59cbb494220b02712572dcc09542954.exe
#
# Resource case changed for 095e1c9c17a0a16e681bce27a3717f1fd3fc9fcbb9157e08144243a706b5b3db.exe
#
# Resource case changed for 1534bb32a757f8261cd698fb3280e52c5c1e6125b78acf18613ed680eacfda43.exe
#
# Resource case changed for 9a97affaa82f98372c109c4be5860f8d445241211aed6683c7642160d9da59dc.exe
#
# Resource case changed for 8aaa4cfcebf57adf1666cf74414a1832276421f4e13e9ccf3a35bebf4c68b89d.exe
#
# Resource case changed for 80b4e80f3971105aa5bbf63bf21b83c0cc52ecbd975dc06e7690534e3c6b3dab.exe
#
# Resource case changed for 2e61521406005d30cae68eb0d664bcdf176b68169a5b3449322b330ae06a01e6.exe
#
# Resource case changed for 7b8be542095ba38e3dcb36d6920e5d552bc9bce2ad6d3afe99beb0ca13d214ec.exe
#
# Resource case changed for c6b0c7084b03d064cf1b1a1c55b25987b61e86d9c271eee90801476c0d841f97.exe
#
# Resource case changed for 344e983cf4e5ed669c16ff15ddf32abd8aaf132c1a2001870a26af4bf5e9b8f7.exe
#
# Resource case changed for 5a656ad2125fb1ca6dc3e65b823410c8b72f054a077261f5bf2333094255f449.exe
#
# Resource case changed for 458aed58f679c67e5f09f6662006d193cb2b9b3d575ae03fb6aa9b61f845bfbd.exe
#
# Resource case changed for feddc3507b1a99e8c279b32928696e068b77ab9144987fa9bef31c47e35c2f37.exe
#
# Resource case changed for 66bc30e561a6ef5ddc82f70154c40ca220dee415c6d5e3f8ca554ac68bb43ba9.exe
#
# Resource case changed for 2c37d78609450c02d998c9e27ad6bc594ae4bf5ae9f789011f6557aa0c50d05e.exe
#
# Resource case changed for 654cc1b271f1fd2e625918b0c8a4afffd99f8531ea63c0bf6fe2a226f8dfb55b.exe
#
# Resource case changed for b481629c75eccf371b42a629ab6c300a305c97b6f1935ea6c053b99188c4752f.exe
#
# Resource case changed for d0c9d3f6353d07423011f259271103372a0a0a7d438f5037f20716e861a5e768.exe
#
# Resource case changed for 3fb7aac84e1c2e393439976e2a98c727e519f9a779402b5f9333be9100b3d4f0.exe
#
# Resource case changed for 586712c933202e26565ffa56889c3004bd33a03a2c415271e1807e8e1275cdae.exe
#
# Resource case changed for b70a9989ed724a7434ad18b7b7a6723b79ad7d8aab775aeb61c9c883b68e0c44.exe
#
# Resource case changed for 6967dc4aa10496fceaac17c984dbd6f04579cc1718e0a7aebd989d45ac9b6cb5.exe
#
# Resource case changed for bd797db9800f48886c12bd67e04ffe228965fd5d72e0dfb697f8dcc30c220454.exe
#
# Resource case changed for a9baaa70e34548588f65894f7f03b418e3673a1cc458e228cb30aa73cf394f49.exe
#
# Resource case changed for 6713c266a1abb7c4e5b2c455189e0e21276106720021ad9ae28b1e1969d1feac.exe
#
# Resource case changed for 215234a0ed9b6810f440965aa23b4075b86820e4b74a3747cddbf9b1ee7d8d28.exe
#
# Resource case changed for 5c7f41fc29bca93586901784b9a571fe8a4ef30da32b6e542f40c9de5dfe7740.exe
#
# Resource case changed for 745f4e65df7ebfd74d1b89ff4ffd4ab5c033f943633dc1cd25fdfed69f2b48bd.exe
#
# Resource case changed for e580757f7cd797e06aab7555e5abe36e7bc8a47ee6bea92f0528319846c77580.exe
#
# Resource case changed for 12a8a9e1e31f675d12fb00967c0f39bc96187d025c843cb3891b869ec7dd3133.exe
#
# Resource case changed for 09e817fa8b7a4b72e30bf4e645d6b238573c50da8d24f323c79a57fbacdc1051.exe
#
# Resource case changed for c73477a9fec5657d96688c6f39763e2eb42951264f87a87d23e41c04336c1454.exe
#
# Resource case changed for 65d0141e3b13d0e983015853affd1af79a10cdc8dde8521160195927d396ab44.exe
#
# Resource case changed for bd5c2429d00750852bb57571cf806227fee37f31a1c25b033fa73772d94305f7.exe
#
# Resource case changed for 7ec5e5dc3b0b4e1be6958dd47d0fdcea9f5940e7d881a79070355b32270a2195.exe
#
# Resource case changed for dd93302af4314e2855b8a9bc25487951b66e3ec0fb53dd34e65444fd6fddf1a3.exe
#
# Resource case changed for 09d6d1c1f4e0f308490eb519200b42d0270811f8b81eac1cb14b488de06053a1.exe
#
# Resource case changed for 9d2094d61c873a7ddac936c8fe11fccf70d0c23f9624a002c9444ab0f3f26519.exe
#
# Resource case changed for b36ccce2bd51d67d9649ff298e1896bd3084c93aa4f6dee096c21bafdd02e022.exe
#
# Resource case changed for b2f4920c89f4bfcc7d1a8e54c842fc8dd087335362069bbd4ddd459ef7831852.exe
#
# Resource case changed for 9bb4e7da44699fb06696c4edbfecd49475fd7dcd6219ead833ceb0e20868c70a.exe
#
# Resource case changed for 1b275307e7004a786d7995f25ec43db82fffbc949d80c8c2adcde6c328f6558f.exe
#
# Resource case changed for 7047468f505a123f56ccbd269d7a068c4386bd8f362c93e1c3debe636872cf49.exe
#
# Resource case changed for 4f6281b5ab13cc7e2a4ed7e8c6e3af578ba8b01b4e8ee87206556760accd28a6.exe
#
# Resource case changed for 3748e567a3cab749c6b963e571ae446f1c11cb128a5bf951afa92d1b4ba4ec8d.exe
#
# Resource case changed for f3fd9fd9606a54148d6cd5dc39f9f8142d311dbb3bc344d9ea59cd4ac66d1c2d.exe
#
# Resource case changed for 1a25fd1b767b81f3cfc1518779b17f29bfd287fa5f298f6f3da10a010d1d8db6.exe
#
# Resource case changed for bb0da8ada92d2d4694c9f143a088a55fe4a6e90d985d18e526ff248b4914b158.exe
#
# Resource case changed for 27c5932d1f057bdea26b63297776e5c583dbaa18448634f2b5c434da95d4f507.exe
#
# Resource case changed for 8617213184f3a4e7136b572f681ec3ecfeb5ec4b255ce5c1860d6cab87731337.exe
#
# Resource case changed for eceba24027681cc42d2d2f3274bd3be8ed36b8e0036bbd7b9978cfc64eb5f6b5.exe
#
# Resource case changed for 73b9489cbf243361313dc03e2082088484627d068311cd27230d1902a5eda941.exe
#
# Resource case changed for b0461d94adfacdb0bae7ab338677499008a25f7766906b336f5bfcc07c213c40.exe
#
# Resource case changed for 6ec3c496e9c309b1db509895d1620046a36bfa1266c5e92237225e8f9ce7de76.exe
#
# Resource case changed for c4d11d32de5a1a822b7df80b6d3967cf4e9bee093e4f632661d9bc6de5c07deb.exe
#
# Resource case changed for b639862b122a9f2a48e3304e87639905b23d7c09fe3657c61d189f8ae472fd43.exe
#
# Resource case changed for 9aaa277e08c11aeb158f5b0bba637e0644ed989ec63a9dd35792b526b1ee3186.exe
#
# Resource case changed for 539ed525b9d70bba9efef76d095475f8ca0660e5619f41f987022c2dea89a269.exe
#
# Resource case changed for 44507cbeb93a99607f6dac3a0afc6a89350341efd079c4699a6bcb9acdb01807.exe
#
# Resource case changed for fb4e50f969b7fcf3f5547ad9b50ed7b2fa00326b952a11a90e75488715504fff.exe
#
# Resource case changed for b6deb448fb39b7fc0f610d0e75fd8f489c2e9312e55064b41a36b9fc87804303.exe
#
# Resource case changed for 4723b9fd6a999150c2bac75aac6b473665c59ef253f0c8a4e0ab2816882d8d0a.exe
#
# Resource case changed for 8c22acaad495361b0e34db8e9d5e929dbad7cd01935597ac0d1a013b55c79814.exe
#
# Resource case changed for 3e0f1bc16bf3d96a1cb435e343787ffaa4fbb8ae871e9651788049dad1b50c04.exe
#
# Resource case changed for 724f6265477070ec6199759eb17aea3ef7ef4c752f5a805f04c1a6a8bee861d8.exe
#
# Resource case changed for 297e066fbdaffa96db4bf2628481a7e6ceb3c222d3306df63d6d1abf85344d53.exe
#
# Resource case changed for 40e89fdad1f9eb06715eb27a7704e185993e9abaf00e8d9593753023fa233247.exe
#
# Resource case changed for 0386d93e49b12c519556b9ead9d29034d911688f317fb4f46f958134c26d2af3.exe
#
# Resource case changed for bf534f389b5a86f9228535ed9c60a919d10da8e99efb38548c3ee3ed278ba66b.exe
#
# Resource case changed for a3e78336c011dcc4ca8384713ff036c8801f1910847c72d0d4a7443c50216f37.exe
#
# Resource case changed for 9d0acf8d55fe086a7d1b8ae853dae14b2e749278895e0c859e2a925bc514066a.exe
#
# Resource case changed for e60f1b1b48459f71781aee8346edfba7bdf5dd6bcf6aed2558df7a6142247cb0.exe
#
# Resource case changed for 88ed12e012f5928df62788fe5849234de4a7e30ccd5f3419c27f7e4846babf9d.exe
#
# Resource case changed for 8f46c0cc5906d2fb33b5a3f9df3c6a45faa4ecbdf87b7a5a97fde7e92aa0e1fc.exe
#
# Resource case changed for ac798bbdee898e0d662b72a4c91ad375bb03fed19dd8755b8233e3304a3f76a5.exe
#
# Resource case changed for a43aae87397c2b59467f01f4ed29d272968be5f4cbdae10343efafe56db98cb2.exe
