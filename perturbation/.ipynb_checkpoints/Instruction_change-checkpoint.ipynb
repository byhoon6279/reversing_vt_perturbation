# %%
from instruction_change import *
from common_function import *

if __name__ == "__main__":
    
    sample_dir = '../sample/input_sample/'
    save_dir = '../sample/perturbated_sample/instruction_change/'
    
    samples = list_files_by_size(sample_dir)
    create_directory(save_dir)

    for sample in samples:
        if '.ipynb' in sample or '.pickle' in sample or '.txt' in sample or '.zip' in sample or '.' not in sample:
            continue
        
        print(sample)

        input_filepath = sample_dir+sample
        
        new_text = disassemble_and_modify(input_filepath, save_dir)
        
        if new_text is None:
            print(f"[+] Error : failed to make new_text section.")
        else:
            new_text = modify_headers(input_filepath, new_text)
            modify_section(input_filepath, new_text, save_dir)
# Out:
# Directory '../sample/perturbated_sample/instruction_change/' created successfully.
# hello_32.exe
# bit :  32
# modified_section :  3584 | original section :  3584 | 3584
# [+] new size of binary : 9216
# Done!! :  ../sample/input_sample/hello_32_changing.exe |  ../sample/perturbated_sample/instruction_change/hello_32_changing.exe
#
# calc.exe
# bit :  64
# modified_section :  3072 | original section :  3072 | 3072
# [+] new size of binary : 27648
# Done!! :  ../sample/input_sample/calc_changing.exe |  ../sample/perturbated_sample/instruction_change/calc_changing.exe
#
# PEview.exe
# bit :  32
# modified_section :  33280 | original section :  33280 | 33280
# [+] new size of binary : 67584
# Done!! :  ../sample/input_sample/PEview_changing.exe |  ../sample/perturbated_sample/instruction_change/PEview_changing.exe
#
# 0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692.exe
# bit :  32
# modified_section :  114688 | original section :  114688 | 114688
# [+] new size of binary : 126976
# Done!! :  ../sample/input_sample/0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692_changing.exe |  ../sample/perturbated_sample/instruction_change/0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692_changing.exe
#
# Frombook.exe
# bit :  32
# modified_section :  184832 | original section :  184832 | 184832
# [+] new size of binary : 185856
# Done!! :  ../sample/input_sample/Frombook_changing.exe |  ../sample/perturbated_sample/instruction_change/Frombook_changing.exe
#
# 05ab5e2da3607795a37d8a9182f7f072a10a9bf3ee6e846f19dfb1c0db71be53.exe
# Failed to find .text section
# [+] Error : failed to make new_text section.
# RemcosRAT.exe
# bit :  32
# modified_section :  356864 | original section :  356864 | 356864
# [+] new size of binary : 494592
# Done!! :  ../sample/input_sample/RemcosRAT_changing.exe |  ../sample/perturbated_sample/instruction_change/RemcosRAT_changing.exe
#
# 20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e.exe
# bit :  32
# modified_section :  412153 | original section :  412160 | 412160
# [+] new size of binary : 638976
# Done!! :  ../sample/input_sample/20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e_changing.exe |  ../sample/perturbated_sample/instruction_change/20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e_changing.exe
#
# 46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29.exe
# bit :  32
# modified_section :  693753 | original section :  693760 | 693760
# [+] new size of binary : 706048
# Done!! :  ../sample/input_sample/46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29_changing.exe |  ../sample/perturbated_sample/instruction_change/46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29_changing.exe
#
# e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2.dll
# bit :  32
# modified_section :  462336 | original section :  462336 | 462336
# [+] new size of binary : 807816
# Done!! :  ../sample/input_sample/e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2_changing.dll |  ../sample/perturbated_sample/instruction_change/e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2_changing.dll
#
# iexplore_32.exe
# bit :  32
# modified_section :  36864 | original section :  36864 | 36864
# [+] new size of binary : 830064
# Done!! :  ../sample/input_sample/iexplore_32_changing.exe |  ../sample/perturbated_sample/instruction_change/iexplore_32_changing.exe
#
# iexplore.exe
# bit :  64
# modified_section :  33792 | original section :  33792 | 33792
# [+] new size of binary : 836600
# Done!! :  ../sample/input_sample/iexplore_changing.exe |  ../sample/perturbated_sample/instruction_change/iexplore_changing.exe
#
# fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd.exe
# bit :  64
# modified_section :  662527 | original section :  662528 | 662528
# [+] new size of binary : 849456
# Done!! :  ../sample/input_sample/fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd_changing.exe |  ../sample/perturbated_sample/instruction_change/fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd_changing.exe
#
# sublime_text_32.exe
# bit :  32
# modified_section :  4990976 | original section :  4990976 | 4990976
# [+] new size of binary : 6896528
# Done!! :  ../sample/input_sample/sublime_text_32_changing.exe |  ../sample/perturbated_sample/instruction_change/sublime_text_32_changing.exe
#
# sublime_text_32-Copy1.exe
# bit :  32
# modified_section :  4990976 | original section :  4990976 | 4990976
# [+] new size of binary : 6896528
# Done!! :  ../sample/input_sample/sublime_text_32-Copy1_changing.exe |  ../sample/perturbated_sample/instruction_change/sublime_text_32-Copy1_changing.exe
#
# sublime_text_64-Copy1.exe
# bit :  64
# modified_section :  6441958 | original section :  6441984 | 6441984
# [+] new size of binary : 9891904
# Done!! :  ../sample/input_sample/sublime_text_64-Copy1_changing.exe |  ../sample/perturbated_sample/instruction_change/sublime_text_64-Copy1_changing.exe
#
# sublime_text_64.exe
# bit :  64
# modified_section :  6441958 | original section :  6441984 | 6441984
# [+] new size of binary : 9891904
# Done!! :  ../sample/input_sample/sublime_text_64_changing.exe |  ../sample/perturbated_sample/instruction_change/sublime_text_64_changing.exe
#
# moba.exe
# bit :  32
# modified_section :  7401403 | original section :  7401472 | 7401472
# [+] new size of binary : 16960424
# Done!! :  ../sample/input_sample/moba_changing.exe |  ../sample/perturbated_sample/instruction_change/moba_changing.exe

# %%
def to_little_endian(hex_str):
    # 2자리씩 끊어서 리스트로 만듭니다.
    bytes_list = [hex_str[i:i+2] for i in range(0, len(hex_str), 2)]
    # 리스트를 역순으로 뒤집습니다.
    bytes_list.reverse()
    # 다시 문자열로 결합합니다.
    little_endian_str = ''.join(bytes_list)
    return little_endian_str
    
def negative_to_little_endian_hex(negative_integer):
    # 음수를 32비트 2의 보수 16진수로 변환
    hex_string = hex(negative_integer & 0xFFFFFFFF)[2:]

    # 16진수 문자열을 8자리로 맞추기 위해 앞에 0을 추가
    hex_string = hex_string.zfill(8)

    # 16진수 문자열을 2자리씩 끊어서 리스트에 저장
    hex_bytes = [hex_string[i:i+2] for i in range(0, len(hex_string), 2)]

    # 바이트 순서를 반전하여 리틀 엔디안으로 변환
    little_endian_hex = ''.join(reversed(hex_bytes))

    return little_endian_hex

def hex_to_signed_int(hex_str):
    value = int(hex_str, 16)
    if value & (1 << (len(hex_str) * 4 - 1)):
        value -= 1 << (len(hex_str) * 4)
    return value

offset = -1 #target_address - present_address - len(instr)
print("3 offset : ",offset)

operand = hex(offset).replace('x','0',1) 
print("4 operand : ",operand)
operand = operand.replace('00','',1)
print("5 operand : ",operand)

if len(operand)%2 !=0:
    new_operand = '0'+operand
    operand = new_operand

operand = to_little_endian(operand)
print("6 operand : ",operand)

if len(operand) != 8:
    operand += '0' * (8-len(operand))    

if offset<0:
    print("  offset 0 : ",offset)
    operand = negative_to_little_endian_hex(offset)
    print("  offset 1 : ",operand)
    operand = operand.replace('x','0',1)
    print("  offset 2 : ",operand)

    while 1:
        if 2 == len(operand):
            break
        else:
            operand = operand.replace('ff','',1)
            
print(operand)
#new_ins = op_code+operand
# Out:
# 3 offset :  -1
# 4 operand :  -001
# 5 operand :  -1
# 6 operand :  -1
# offset :  -1
# ffffffff
# ff
