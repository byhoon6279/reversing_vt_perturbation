# %%
from instruction_change import *
from common_function import *

if __name__ == "__main__":
    
    sample_dir = '../sample/input_sample/'
    save_dir = '../sample/perturbated_sample/instruction_change/'
    
    samples = list_files_by_size(sample_dir)
    create_directory(save_dir)

    for sample in samples:
        if '.ipynb' in sample or '.pickle' in sample or '.txt' in sample or '.zip' in sample or '.' not in sample:
            continue
        
        print(sample)

        input_filepath = sample_dir+sample
        
        new_text = disassemble_and_modify(input_filepath, save_dir)
        
        if new_text is None:
            print(f"[+] Error : failed to make new_text section.")
        else:
            new_text = modify_headers(input_filepath, new_text)
            modify_section(input_filepath, new_text, save_dir)
# Out:
# Directory '../perturbated_sample/instruction_change/' created successfully.
# 46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29.exe
# bit :  32
# modified_section :  693753 | original section :  693760 | 693760
# [+] new size of binary : 706048
# Done!! :  ../sample/46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29_changing.exe |  ../perturbated_sample/instruction_change/46bc59c333ac61690a6514b21b84a7a0d8a7f191f7ae91b9afd6957a2b8f7c29_changing.exe
#
# sublime_text_32.exe
# bit :  32
# modified_section :  4990976 | original section :  4990976 | 4990976
# [+] new size of binary : 6896528
# Done!! :  ../sample/sublime_text_32_changing.exe |  ../perturbated_sample/instruction_change/sublime_text_32_changing.exe
#
# e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2.dll
# bit :  32
# modified_section :  462336 | original section :  462336 | 462336
# [+] new size of binary : 807816
# Done!! :  ../sample/e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2_changing.dll |  ../perturbated_sample/instruction_change/e2a24ab94f865caeacdf2c3ad015f31f23008ac6db8312c2cbfb32e4a5466ea2_changing.dll
#
# 05ab5e2da3607795a37d8a9182f7f072a10a9bf3ee6e846f19dfb1c0db71be53.exe
# Failed to find .text section
# [+] Error : failed to make new_text section.
# iexplore_32.exe
# bit :  32
# modified_section :  36864 | original section :  36864 | 36864
# [+] new size of binary : 830064
# Done!! :  ../sample/iexplore_32_changing.exe |  ../perturbated_sample/instruction_change/iexplore_32_changing.exe
#
# Frombook.exe
# bit :  32
# modified_section :  184832 | original section :  184832 | 184832
# [+] new size of binary : 185856
# Done!! :  ../sample/Frombook_changing.exe |  ../perturbated_sample/instruction_change/Frombook_changing.exe
#
# PEview.exe
# bit :  32
# modified_section :  33280 | original section :  33280 | 33280
# [+] new size of binary : 67584
# Done!! :  ../sample/PEview_changing.exe |  ../perturbated_sample/instruction_change/PEview_changing.exe
#
# 0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692.exe
# bit :  32
# modified_section :  114688 | original section :  114688 | 114688
# [+] new size of binary : 126976
# Done!! :  ../sample/0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692_changing.exe |  ../perturbated_sample/instruction_change/0c34ed46c75b33e392091d8fb7b4449b2fd78b6a56ae7d89f5e6441c48f10692_changing.exe
#
# moba.exe
# bit :  32
# modified_section :  7401403 | original section :  7401472 | 7401472
# [+] new size of binary : 16960424
# Done!! :  ../sample/moba_changing.exe |  ../perturbated_sample/instruction_change/moba_changing.exe
#
# iexplore.exe
# bit :  64
# modified_section :  33792 | original section :  33792 | 33792
# [+] new size of binary : 836600
# Done!! :  ../sample/iexplore_changing.exe |  ../perturbated_sample/instruction_change/iexplore_changing.exe
#
# 20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e.exe
# bit :  32
# modified_section :  412153 | original section :  412160 | 412160
# [+] new size of binary : 638976
# Done!! :  ../sample/20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e_changing.exe |  ../perturbated_sample/instruction_change/20004cf75c3ffef4a7cb3784b631eb74b93e9abe27509169d96094904e40f66e_changing.exe
#
# RemcosRAT.exe
# bit :  32
# modified_section :  356864 | original section :  356864 | 356864
# [+] new size of binary : 494592
# Done!! :  ../sample/RemcosRAT_changing.exe |  ../perturbated_sample/instruction_change/RemcosRAT_changing.exe
#
# sublime_text_64-Copy1.exe
# bit :  64
# modified_section :  6441958 | original section :  6441984 | 6441984
# [+] new size of binary : 9891904
# Done!! :  ../sample/sublime_text_64-Copy1_changing.exe |  ../perturbated_sample/instruction_change/sublime_text_64-Copy1_changing.exe
#
# fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd.exe
# bit :  64
# modified_section :  662527 | original section :  662528 | 662528
# [+] new size of binary : 849456
# Done!! :  ../sample/fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd_changing.exe |  ../perturbated_sample/instruction_change/fe517edc4af057efe776a69465466504c72fb6a15177c25a3414360e08ca92dd_changing.exe
#
# calc.exe
# bit :  64
# modified_section :  3072 | original section :  3072 | 3072
# [+] new size of binary : 27648
# Done!! :  ../sample/calc_changing.exe |  ../perturbated_sample/instruction_change/calc_changing.exe
#
# sublime_text_64.exe
# bit :  64
# modified_section :  6441958 | original section :  6441984 | 6441984
# [+] new size of binary : 9891904
# Done!! :  ../sample/sublime_text_64_changing.exe |  ../perturbated_sample/instruction_change/sublime_text_64_changing.exe
#
# sublime_text_32-Copy1.exe
# bit :  32
# modified_section :  4990976 | original section :  4990976 | 4990976
# [+] new size of binary : 6896528
# Done!! :  ../sample/sublime_text_32-Copy1_changing.exe |  ../perturbated_sample/instruction_change/sublime_text_32-Copy1_changing.exe
